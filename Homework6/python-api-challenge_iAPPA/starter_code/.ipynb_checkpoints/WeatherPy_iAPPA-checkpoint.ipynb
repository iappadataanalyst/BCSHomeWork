# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 584

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#base_url = "http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=imperial&q="
#query_url = base_url + city

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"#"metric"
# set up lists to hold reponse info
cloudiness = []
city_new =[]
country  = []
date = []
humidity = []
lat=[]
lan=[]
speed=[]
maxtemp=[]

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
print("Beginning Data Retrieval")    
print("-----------------------------")  
i=1
j=1
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lan.append(response['coord']['lon'])
        maxtemp.append(response['main']['temp_max'])
        speed.append(response['wind']['speed'])
        
        print("Processing Record "+str(i) + " of Set " + str(j) +" | " + city)
        city_new.append(city)
        
        i=i+1 
        if i == 50 :
            i=0
            j = j+1
    except KeyError:
        print("City not found. Skipping...")
print("-----------------------------")    
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | cabo san lucas
# Processing Record 2 of Set 1 | port lincoln
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | bengkulu
# Processing Record 5 of Set 1 | kruisfontein
# Processing Record 6 of Set 1 | hilo
# Processing Record 7 of Set 1 | kiama
# Processing Record 8 of Set 1 | tiksi
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | hermanus
# Processing Record 11 of Set 1 | cherskiy
# Processing Record 12 of Set 1 | mataura
# Processing Record 13 of Set 1 | laem sing
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | evensk
# Processing Record 17 of Set 1 | mae ramat
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | dejen
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | bluff
# Processing Record 22 of Set 1 | borogontsy
# Processing Record 23 of Set 1 | tulghes
# Processing Record 24 of Set 1 | atuona
# Processing Record 25 of Set 1 | poum
# Processing Record 26 of Set 1 | jamestown
# Processing Record 27 of Set 1 | padang
# Processing Record 28 of Set 1 | adelaide
# Processing Record 29 of Set 1 | te anau
# Processing Record 30 of Set 1 | castro
# Processing Record 31 of Set 1 | puerto ayora
# Processing Record 32 of Set 1 | yerofey pavlovich
# Processing Record 33 of Set 1 | lavrentiya
# Processing Record 34 of Set 1 | hobyo
# Processing Record 35 of Set 1 | mount gambier
# Processing Record 36 of Set 1 | houma
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | vestmannaeyjar
# Processing Record 40 of Set 1 | tura
# Processing Record 41 of Set 1 | saint george
# Processing Record 42 of Set 1 | mandalgovi
# Processing Record 43 of Set 1 | vanavara
# Processing Record 44 of Set 1 | banda aceh
# Processing Record 45 of Set 1 | geraldton
# Processing Record 46 of Set 1 | hit
# Processing Record 47 of Set 1 | hobart
# City not found. Skipping...
# Processing Record 48 of Set 1 | kavieng
# Processing Record 49 of Set 1 | pevek
# Processing Record 0 of Set 2 | raglan
# Processing Record 1 of Set 2 | vila velha
# Processing Record 2 of Set 2 | bull savanna
# Processing Record 3 of Set 2 | saint-pierre
# Processing Record 4 of Set 2 | fairbanks
# Processing Record 5 of Set 2 | vitim
# Processing Record 6 of Set 2 | bathsheba
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | saint-philippe
# Processing Record 9 of Set 2 | sivaki
# Processing Record 10 of Set 2 | marshall
# City not found. Skipping...
# Processing Record 11 of Set 2 | margate
# Processing Record 12 of Set 2 | lorengau
# Processing Record 13 of Set 2 | hasaki
# City not found. Skipping...
# Processing Record 14 of Set 2 | mountain home
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | ambilobe
# Processing Record 17 of Set 2 | stephenville
# Processing Record 18 of Set 2 | yar-sale
# Processing Record 19 of Set 2 | avarua
# Processing Record 20 of Set 2 | thompson
# Processing Record 21 of Set 2 | moose factory
# Processing Record 22 of Set 2 | busselton
# Processing Record 23 of Set 2 | akcakoca
# Processing Record 24 of Set 2 | iqaluit
# Processing Record 25 of Set 2 | kutum
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | huaihua
# Processing Record 28 of Set 2 | juneau
# Processing Record 29 of Set 2 | coihaique
# Processing Record 30 of Set 2 | udachnyy
# Processing Record 31 of Set 2 | sarkand
# Processing Record 32 of Set 2 | quatre cocos
# Processing Record 33 of Set 2 | caico
# Processing Record 34 of Set 2 | palmer
# Processing Record 35 of Set 2 | high level
# Processing Record 36 of Set 2 | kholm
# Processing Record 37 of Set 2 | balkhash
# Processing Record 38 of Set 2 | aykhal
# Processing Record 39 of Set 2 | krasnoselkup
# Processing Record 40 of Set 2 | frederico westphalen
# Processing Record 41 of Set 2 | manggar
# Processing Record 42 of Set 2 | quesnel
# Processing Record 43 of Set 2 | howard springs
# City not found. Skipping...
# Processing Record 44 of Set 2 | georgetown
# Processing Record 45 of Set 2 | kahului
# Processing Record 46 of Set 2 | chokurdakh
# City not found. Skipping...
# Processing Record 47 of Set 2 | chuy
# Processing Record 48 of Set 2 | san cristobal
# Processing Record 49 of Set 2 | faya
# Processing Record 0 of Set 3 | kodiak
# Processing Record 1 of Set 3 | mar del plata
# Processing Record 2 of Set 3 | ribeira grande
# Processing Record 3 of Set 3 | singleton
# Processing Record 4 of Set 3 | sao filipe
# Processing Record 5 of Set 3 | provideniya
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 3 | leningradskiy
# City not found. Skipping...
# Processing Record 7 of Set 3 | ponta do sol
# Processing Record 8 of Set 3 | yumen
# Processing Record 9 of Set 3 | requena
# Processing Record 10 of Set 3 | punta arenas
# Processing Record 11 of Set 3 | rocha
# Processing Record 12 of Set 3 | bambanglipuro
# Processing Record 13 of Set 3 | tasiilaq
# Processing Record 14 of Set 3 | gizo
# City not found. Skipping...
# Processing Record 15 of Set 3 | airai
# Processing Record 16 of Set 3 | peniche
# Processing Record 17 of Set 3 | ahipara
# Processing Record 18 of Set 3 | mundo nuevo
# Processing Record 19 of Set 3 | nemuro
# Processing Record 20 of Set 3 | enumclaw
# Processing Record 21 of Set 3 | saint anthony
# Processing Record 22 of Set 3 | yellowknife
# Processing Record 23 of Set 3 | ilulissat
# Processing Record 24 of Set 3 | bredasdorp
# Processing Record 25 of Set 3 | cape town
# City not found. Skipping...
# Processing Record 26 of Set 3 | ust-kuyga
# Processing Record 27 of Set 3 | tucumcari
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | khani
# Processing Record 30 of Set 3 | severo-kurilsk
# City not found. Skipping...
# Processing Record 31 of Set 3 | narsaq
# Processing Record 32 of Set 3 | puerto escondido
# City not found. Skipping...
# Processing Record 33 of Set 3 | port elizabeth
# Processing Record 34 of Set 3 | upernavik
# Processing Record 35 of Set 3 | nome
# Processing Record 36 of Set 3 | fort nelson
# Processing Record 37 of Set 3 | labuhan
# Processing Record 38 of Set 3 | nikolskoye
# Processing Record 39 of Set 3 | imbituba
# Processing Record 40 of Set 3 | belen
# Processing Record 41 of Set 3 | hithadhoo
# Processing Record 42 of Set 3 | bambous virieux
# Processing Record 43 of Set 3 | mukhen
# Processing Record 44 of Set 3 | ahuimanu
# Processing Record 45 of Set 3 | cayenne
# Processing Record 46 of Set 3 | grand forks
# Processing Record 47 of Set 3 | severomuysk
# Processing Record 48 of Set 3 | fairlie
# Processing Record 49 of Set 3 | mahibadhoo
# Processing Record 0 of Set 4 | isangel
# Processing Record 1 of Set 4 | cidreira
# Processing Record 2 of Set 4 | pangnirtung
# Processing Record 3 of Set 4 | faanui
# Processing Record 4 of Set 4 | butaritari
# City not found. Skipping...
# Processing Record 5 of Set 4 | port alfred
# Processing Record 6 of Set 4 | terrasini
# Processing Record 7 of Set 4 | ayagoz
# Processing Record 8 of Set 4 | zhangjiakou
# Processing Record 9 of Set 4 | tshikapa
# City not found. Skipping...
# Processing Record 10 of Set 4 | antsohihy
# Processing Record 11 of Set 4 | esperance
# Processing Record 12 of Set 4 | luderitz
# Processing Record 13 of Set 4 | vladivostok
# City not found. Skipping...
# Processing Record 14 of Set 4 | chabahar
# Processing Record 15 of Set 4 | jizan
# Processing Record 16 of Set 4 | cururupu
# Processing Record 17 of Set 4 | komsomolskiy
# Processing Record 18 of Set 4 | skopin
# Processing Record 19 of Set 4 | santa cruz
# Processing Record 20 of Set 4 | hambantota
# Processing Record 21 of Set 4 | ketchikan
# Processing Record 22 of Set 4 | shahr-e kord
# Processing Record 23 of Set 4 | grindavik
# Processing Record 24 of Set 4 | bagdarin
# Processing Record 25 of Set 4 | port hardy
# Processing Record 26 of Set 4 | plettenberg bay
# Processing Record 27 of Set 4 | talnakh
# Processing Record 28 of Set 4 | manokwari
# Processing Record 29 of Set 4 | kidal
# Processing Record 30 of Set 4 | tuktoyaktuk
# Processing Record 31 of Set 4 | punta alta
# Processing Record 32 of Set 4 | butembo
# City not found. Skipping...
# Processing Record 33 of Set 4 | tomatlan
# Processing Record 34 of Set 4 | zhangye
# Processing Record 35 of Set 4 | bianzhuang
# Processing Record 36 of Set 4 | ridgecrest
# Processing Record 37 of Set 4 | katherine
# Processing Record 38 of Set 4 | navashino
# Processing Record 39 of Set 4 | saint-joseph
# Processing Record 40 of Set 4 | husavik
# Processing Record 41 of Set 4 | qaanaaq
# City not found. Skipping...
# Processing Record 42 of Set 4 | lubango
# Processing Record 43 of Set 4 | nanakuli
# Processing Record 44 of Set 4 | camacha
# Processing Record 45 of Set 4 | sorland
# Processing Record 46 of Set 4 | kroya
# Processing Record 47 of Set 4 | alofi
# Processing Record 48 of Set 4 | port hawkesbury
# Processing Record 49 of Set 4 | riyadh
# Processing Record 0 of Set 5 | mbini
# Processing Record 1 of Set 5 | puxinana
# Processing Record 2 of Set 5 | haines junction
# Processing Record 3 of Set 5 | vadso
# Processing Record 4 of Set 5 | longyearbyen
# Processing Record 5 of Set 5 | walvis bay
# City not found. Skipping...
# Processing Record 6 of Set 5 | arlit
# Processing Record 7 of Set 5 | prince rupert
# Processing Record 8 of Set 5 | dingzhou
# Processing Record 9 of Set 5 | souillac
# Processing Record 10 of Set 5 | morozovsk
# Processing Record 11 of Set 5 | baykit
# Processing Record 12 of Set 5 | kamenka
# City not found. Skipping...
# Processing Record 13 of Set 5 | sitka
# Processing Record 14 of Set 5 | raudeberg
# Processing Record 15 of Set 5 | lakselv
# Processing Record 16 of Set 5 | pochutla
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 5 | alamosa
# Processing Record 18 of Set 5 | bhikangaon
# Processing Record 19 of Set 5 | salalah
# Processing Record 20 of Set 5 | lompoc
# Processing Record 21 of Set 5 | uenohara
# Processing Record 22 of Set 5 | rosarito
# Processing Record 23 of Set 5 | torbay
# Processing Record 24 of Set 5 | gurupa
# Processing Record 25 of Set 5 | azare
# Processing Record 26 of Set 5 | andilamena
# Processing Record 27 of Set 5 | siavonga
# Processing Record 28 of Set 5 | marquette
# Processing Record 29 of Set 5 | sena madureira
# Processing Record 30 of Set 5 | altamira
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 5 | norman wells
# Processing Record 32 of Set 5 | kurilsk
# Processing Record 33 of Set 5 | shalya
# Processing Record 34 of Set 5 | new norfolk
# Processing Record 35 of Set 5 | dikson
# Processing Record 36 of Set 5 | biak
# Processing Record 37 of Set 5 | mount isa
# City not found. Skipping...
# Processing Record 38 of Set 5 | hofn
# Processing Record 39 of Set 5 | yumbing
# Processing Record 40 of Set 5 | malkara
# Processing Record 41 of Set 5 | hovd
# Processing Record 42 of Set 5 | florence
# Processing Record 43 of Set 5 | nizhneangarsk
# City not found. Skipping...
# Processing Record 44 of Set 5 | maniitsoq
# Processing Record 45 of Set 5 | khatanga
# Processing Record 46 of Set 5 | silver city
# Processing Record 47 of Set 5 | ust-karsk
# Processing Record 48 of Set 5 | dingle
# Processing Record 49 of Set 5 | singaraja
# Processing Record 0 of Set 6 | pizarro
# Processing Record 1 of Set 6 | sao jose da coroa grande
# City not found. Skipping...
# Processing Record 2 of Set 6 | alice springs
# Processing Record 3 of Set 6 | hyeres
# Processing Record 4 of Set 6 | wanning
# Processing Record 5 of Set 6 | kirovsk
# Processing Record 6 of Set 6 | kushiro
# Processing Record 7 of Set 6 | ostrovnoy
# Processing Record 8 of Set 6 | paidha
# Processing Record 9 of Set 6 | methoni
# Processing Record 10 of Set 6 | sobolevo
# City not found. Skipping...
# Processing Record 11 of Set 6 | guerrero negro
# Processing Record 12 of Set 6 | el alto
# Processing Record 13 of Set 6 | itarsi
# Processing Record 14 of Set 6 | kissidougou
# Processing Record 15 of Set 6 | loikaw
# Processing Record 16 of Set 6 | langsa
# City not found. Skipping...
# Processing Record 17 of Set 6 | gedo
# Processing Record 18 of Set 6 | ibotirama
# Processing Record 19 of Set 6 | nioaque
# City not found. Skipping...
# Processing Record 20 of Set 6 | nouakchott
# City not found. Skipping...
# Processing Record 21 of Set 6 | codrington
# Processing Record 22 of Set 6 | avera
# City not found. Skipping...
# Processing Record 23 of Set 6 | ypsonas
# Processing Record 24 of Set 6 | gejiu
# Processing Record 25 of Set 6 | pocone
# Processing Record 26 of Set 6 | broome
# Processing Record 27 of Set 6 | beringovskiy
# Processing Record 28 of Set 6 | bereda
# Processing Record 29 of Set 6 | sola
# Processing Record 30 of Set 6 | igarka
# Processing Record 31 of Set 6 | victoria
# Processing Record 32 of Set 6 | yeppoon
# Processing Record 33 of Set 6 | moa
# Processing Record 34 of Set 6 | turtas
# Processing Record 35 of Set 6 | nadudvar
# Processing Record 36 of Set 6 | zarinsk
# Processing Record 37 of Set 6 | katsuura
# Processing Record 38 of Set 6 | buraydah
# City not found. Skipping...
# Processing Record 39 of Set 6 | gilbues
# Processing Record 40 of Set 6 | saint-francois
# Processing Record 41 of Set 6 | vardo
# Processing Record 42 of Set 6 | arraial do cabo
# Processing Record 43 of Set 6 | huayucachi
# Processing Record 44 of Set 6 | san vicente
# Processing Record 45 of Set 6 | korla
# Processing Record 46 of Set 6 | meadow lake
# Processing Record 47 of Set 6 | gisborne
# Processing Record 48 of Set 6 | waipawa
# Processing Record 49 of Set 6 | sangar
# Processing Record 0 of Set 7 | verkhnyaya sysert
# Processing Record 1 of Set 7 | vao
# Processing Record 2 of Set 7 | chapais
# Processing Record 3 of Set 7 | bilibino
# Processing Record 4 of Set 7 | srednekolymsk
# City not found. Skipping...
# Processing Record 5 of Set 7 | kloulklubed
# Processing Record 6 of Set 7 | inhambane
# Processing Record 7 of Set 7 | kungurtug
# Processing Record 8 of Set 7 | kamaishi
# Processing Record 9 of Set 7 | qasigiannguit
# Processing Record 10 of Set 7 | tamale
# Processing Record 11 of Set 7 | berlevag
# Processing Record 12 of Set 7 | constitucion
# Processing Record 13 of Set 7 | iquitos
# Processing Record 14 of Set 7 | turukhansk
# Processing Record 15 of Set 7 | florianopolis
# Processing Record 16 of Set 7 | hirara
# Processing Record 17 of Set 7 | mitsamiouli
# Processing Record 18 of Set 7 | aljezur
# Processing Record 19 of Set 7 | benguela
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 20 of Set 7 | nouadhibou
# Processing Record 21 of Set 7 | bestobe
# Processing Record 22 of Set 7 | derzhavinsk
# Processing Record 23 of Set 7 | kununurra
# Processing Record 24 of Set 7 | shelburne
# Processing Record 25 of Set 7 | chapulhuacan
# Processing Record 26 of Set 7 | santa isabel do rio negro
# Processing Record 27 of Set 7 | chokwe
# Processing Record 28 of Set 7 | marrakesh
# Processing Record 29 of Set 7 | pombos
# Processing Record 30 of Set 7 | port macquarie
# Processing Record 31 of Set 7 | turbat
# Processing Record 32 of Set 7 | jalu
# Processing Record 33 of Set 7 | ancud
# Processing Record 34 of Set 7 | arman
# Processing Record 35 of Set 7 | bayburt
# Processing Record 36 of Set 7 | victoria point
# Processing Record 37 of Set 7 | arvi
# Processing Record 38 of Set 7 | moussoro
# Processing Record 39 of Set 7 | villa bruzual
# Processing Record 40 of Set 7 | indian head
# Processing Record 41 of Set 7 | ellisras
# Processing Record 42 of Set 7 | oshawa
# City not found. Skipping...
# Processing Record 43 of Set 7 | klichka
# Processing Record 44 of Set 7 | bentiu
# Processing Record 45 of Set 7 | back mountain
# Processing Record 46 of Set 7 | darnah
# Processing Record 47 of Set 7 | rapid valley
# Processing Record 48 of Set 7 | balkanabat
# Processing Record 49 of Set 7 | casablanca
# City not found. Skipping...
# Processing Record 0 of Set 8 | upata
# Processing Record 1 of Set 8 | namibe
# Processing Record 2 of Set 8 | casper
# Processing Record 3 of Set 8 | umm lajj
# Processing Record 4 of Set 8 | lasa
# Processing Record 5 of Set 8 | carutapera
# Processing Record 6 of Set 8 | abha
# Processing Record 7 of Set 8 | bundaberg
# Processing Record 8 of Set 8 | natal
# Processing Record 9 of Set 8 | bernalillo
# City not found. Skipping...
# Processing Record 10 of Set 8 | kuala terengganu
# Processing Record 11 of Set 8 | naze
# Processing Record 12 of Set 8 | denpasar
# City not found. Skipping...
# Processing Record 13 of Set 8 | saint-georges
# Processing Record 14 of Set 8 | viedma
# Processing Record 15 of Set 8 | sovetskiy
# Processing Record 16 of Set 8 | adre
# Processing Record 17 of Set 8 | hondo
# Processing Record 18 of Set 8 | dulyapino
# Processing Record 19 of Set 8 | aswan
# Processing Record 20 of Set 8 | lagoa
# Processing Record 21 of Set 8 | santa cruz de tenerife
# Processing Record 22 of Set 8 | filadelfia
# Processing Record 23 of Set 8 | tautira
# Processing Record 24 of Set 8 | ures
# City not found. Skipping...
# Processing Record 25 of Set 8 | bethel
# Processing Record 26 of Set 8 | omsukchan
# Processing Record 27 of Set 8 | flin flon
# Processing Record 28 of Set 8 | nanortalik
# Processing Record 29 of Set 8 | asau
# Processing Record 30 of Set 8 | aksarka
# Processing Record 31 of Set 8 | xunchang
# Processing Record 32 of Set 8 | urucui
# Processing Record 33 of Set 8 | waingapu
# Processing Record 34 of Set 8 | neuquen
# Processing Record 35 of Set 8 | excelsior springs
# Processing Record 36 of Set 8 | qandala
# Processing Record 37 of Set 8 | khilok
# Processing Record 38 of Set 8 | misratah
# Processing Record 39 of Set 8 | maraa
# Processing Record 40 of Set 8 | lamar
# Processing Record 41 of Set 8 | puli
# Processing Record 42 of Set 8 | marsa matruh
# Processing Record 43 of Set 8 | launceston
# City not found. Skipping...
# Processing Record 44 of Set 8 | port moresby
# Processing Record 45 of Set 8 | clyde river
# Processing Record 46 of Set 8 | general roca
# Processing Record 47 of Set 8 | santa helena de goias
# Processing Record 48 of Set 8 | hamilton
# Processing Record 49 of Set 8 | santa lucia
# Processing Record 0 of Set 9 | otane
# Processing Record 1 of Set 9 | samarai
# Processing Record 2 of Set 9 | morros
# Processing Record 3 of Set 9 | boyolangu
# Processing Record 4 of Set 9 | moshenskoye
# Processing Record 5 of Set 9 | the pas
# Processing Record 6 of Set 9 | jandaia do sul
# Processing Record 7 of Set 9 | mahon
# Processing Record 8 of Set 9 | sal rei
# Processing Record 9 of Set 9 | wajir
# Processing Record 10 of Set 9 | guarapari
# Processing Record 11 of Set 9 | marzuq
# Processing Record 12 of Set 9 | khor
# Processing Record 13 of Set 9 | grande prairie
# City not found. Skipping...
# Processing Record 14 of Set 9 | pacific grove
# Processing Record 15 of Set 9 | phuket
# Processing Record 16 of Set 9 | urusha
# Processing Record 17 of Set 9 | shalakusha
# City not found. Skipping...
# Processing Record 18 of Set 9 | barmer
# Processing Record 19 of Set 9 | shasta lake
# Processing Record 20 of Set 9 | cuamba
# Processing Record 21 of Set 9 | linxia
# Processing Record 22 of Set 9 | aklavik
# Processing Record 23 of Set 9 | ballina
# Processing Record 24 of Set 9 | dubovskoye
# City not found. Skipping...
# Processing Record 25 of Set 9 | muros
# Processing Record 26 of Set 9 | cervo
# Processing Record 27 of Set 9 | maneadero
# Processing Record 28 of Set 9 | taltal
# City not found. Skipping...
# Processing Record 29 of Set 9 | xining
# Processing Record 30 of Set 9 | bojnurd
# Processing Record 31 of Set 9 | paso de los toros
# Processing Record 32 of Set 9 | salinopolis
# Processing Record 33 of Set 9 | bilma
# Processing Record 34 of Set 9 | harper
# Processing Record 35 of Set 9 | college
# Processing Record 36 of Set 9 | mackay
# Processing Record 37 of Set 9 | belle fourche
# Processing Record 38 of Set 9 | anadyr
# Processing Record 39 of Set 9 | zaysan
# Processing Record 40 of Set 9 | juazeiro
# Processing Record 41 of Set 9 | olopa
# Processing Record 42 of Set 9 | kalamare
# Processing Record 43 of Set 9 | los llanos de aridane
# Processing Record 44 of Set 9 | vientiane
# Processing Record 45 of Set 9 | mattru
# Processing Record 46 of Set 9 | dwarka
# Processing Record 47 of Set 9 | strangnas
# Processing Record 48 of Set 9 | pisco
# Processing Record 49 of Set 9 | baiyin
# Processing Record 0 of Set 10 | chicama
# Processing Record 1 of Set 10 | takaka
# City not found. Skipping...
# Processing Record 2 of Set 10 | orlik
# Processing Record 3 of Set 10 | kui buri
# Processing Record 4 of Set 10 | westport
# Processing Record 5 of Set 10 | da lat
# Processing Record 6 of Set 10 | honiara
# City not found. Skipping...
# Processing Record 7 of Set 10 | pisz
# Processing Record 8 of Set 10 | mnogovershinnyy
# Processing Record 9 of Set 10 | mahebourg
# Processing Record 10 of Set 10 | san patricio
# Processing Record 11 of Set 10 | cumana
# Processing Record 12 of Set 10 | diego de almagro
# Processing Record 13 of Set 10 | hualmay
# Processing Record 14 of Set 10 | namatanai
# Processing Record 15 of Set 10 | sistranda
# Processing Record 16 of Set 10 | puerto narino
# Processing Record 17 of Set 10 | abu dhabi
# Processing Record 18 of Set 10 | puerto carreno
# Processing Record 19 of Set 10 | kangaatsiaq
# Processing Record 20 of Set 10 | sept-iles
# Processing Record 21 of Set 10 | enshi
# Processing Record 22 of Set 10 | lagos
# Processing Record 23 of Set 10 | lufilufi
# Processing Record 24 of Set 10 | kuusamo
# Processing Record 25 of Set 10 | touros
# Processing Record 26 of Set 10 | hare bay
# Processing Record 27 of Set 10 | fortuna
# Processing Record 28 of Set 10 | sibolga
# Processing Record 29 of Set 10 | amposta
# Processing Record 30 of Set 10 | pithiviers
# Processing Record 31 of Set 10 | adrar
# Processing Record 32 of Set 10 | oshikango
# Processing Record 33 of Set 10 | les cayes
# Processing Record 34 of Set 10 | bandar-e lengeh
# Processing Record 35 of Set 10 | aden
# Processing Record 36 of Set 10 | ewa beach
# Processing Record 37 of Set 10 | takoradi
# Processing Record 38 of Set 10 | akyab
# Processing Record 39 of Set 10 | kaeo
# Processing Record 40 of Set 10 | qaqortoq
# Processing Record 41 of Set 10 | rawah
# Processing Record 42 of Set 10 | kingisepp
# Processing Record 43 of Set 10 | dunedin
# Processing Record 44 of Set 10 | christchurch
# City not found. Skipping...
# Processing Record 45 of Set 10 | tuatapere
# Processing Record 46 of Set 10 | whitefish
# Processing Record 47 of Set 10 | la ronge
# City not found. Skipping...
# Processing Record 48 of Set 10 | beipiao
# Processing Record 49 of Set 10 | innisfail
# Processing Record 0 of Set 11 | cranbourne
# City not found. Skipping...
# Processing Record 1 of Set 11 | itupiranga
# Processing Record 2 of Set 11 | gat
# Processing Record 3 of Set 11 | vila franca do campo
# Processing Record 4 of Set 11 | lujan
# Processing Record 5 of Set 11 | ilhabela
# Processing Record 6 of Set 11 | ziro
# Processing Record 7 of Set 11 | maxixe
# Processing Record 8 of Set 11 | kavaratti
# Processing Record 9 of Set 11 | san carlos de bariloche

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_new,
    "Cloudiness": cloudiness,
    "Country": country,
    "Date":date,
    "Humidity":humidity,
    "Lat":lat,
    "Lng":lan,
    "Max Temp":maxtemp,
    "Wind Speed":speed    
}
weather_data_df = pd.DataFrame(weather_dict)


weather_data_df.count()

# %%
#Export the city data into a .csv.
weather_data_df.to_csv("../"+ output_data_file, index=False, header=True)

# %%
#Display the DataFrame
weather_data_df.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# chart1 Latitude vs. Temperature Plot
date=time.strftime("%m/%d/%Y")

chart1= weather_data_df.plot(kind="scatter",x="Lat",y="Max Temp",grid=True,marker='o',s=40,edgecolors="black", linewidth=1)
chart1.set_xlabel("Latitude")
chart1.set_ylim(-5,110)
chart1.set_ylabel("Max Temperature (F)")
chart1.set_title("City Latitude Vs. Max Temperature (" +date + ")")
plt.savefig("../output_data/LatvsTempplot.png")

# %%
#In the above plot(Latitude Vs Max Temp) observed  that moving to north is more colder than moving towards south.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# chart2 Latitude vs. Humidity Plot

chart2= weather_data_df.plot(kind="scatter",x="Lat",y="Humidity",grid=True,marker='o',s=40,edgecolors="black", linewidth=1)
chart2.set_xlabel("Latitude")
chart2.set_ylabel("Humidity (%)")
chart2.set_ylim(0,300)
chart2.set_title("City Latitude Vs. Humidity(" + date + ")")
plt.savefig("../output_data/LatvsHumplot.png")

# %%
#In the above plot(Latitude Vs Humidity) for most of cities the humidity %  range did not differ with latitude

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
#chart3 Latitude vs. Cloudiness Plot
chart3= weather_data_df.plot(kind="scatter",x="Lat",y="Cloudiness",grid=True,marker='o',
                             s=40,edgecolors="black", linewidth=1)
chart3.set_xlabel("Latitude")
chart3.set_ylabel("Cloudiness (%)")
chart3.set_ylim(-5,110)
chart3.set_title("City Latitude Vs. Cloudiness(" + date + ")")
plt.savefig("../output_data/LatvsClouplot.png")

# %%
#In the above plot(Latitude Vs Cloudiness) the cloudiness in cities do not have a significant relationship with latitude

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# chart4 Latitude vs. Wind Speed Plot

chart4= weather_data_df.plot(kind="scatter",x="Lat",y="Wind Speed",grid=True,marker='o',s=40,edgecolors="black",
                             linewidth=1)
chart4.set_xlabel("Latitude")
chart4.set_ylabel("Wind Speed (mph)")
chart4.set_ylim(-5,50)
chart4.set_title("City Latitude Vs. Wind Speed(" + date + ")")

plt.savefig("../output_data/LatvsWindspeedplot.png")

# %%
#In the above plot(Latitude Vs windspeed) most of cities the windspeed is between 0 to 20 mph,
# with a non significant increase towards north pole.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def linear_regression_plot(x_value,y_value,pole,x_axis_title,y_axis_title,title,x_cor,y_cor):

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    regress_values = x_value * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Plot scatter plot
    plt.scatter(x_value,y_value)

# Plot regression line
    plt.plot(x_value,regress_values,"r-")
    plt.annotate(line_eq,(x_cor,y_cor),fontsize=15,color="red")

# Label plot
    plt.xlabel(x_axis_title)
    plt.ylabel(y_axis_title)
    plt.title(title,fontsize=14, fontweight="bold")

# Print r square value
    print(f"The r-squared is: {rvalue}")
    output_file = "../output_data/" + pole + x_axis_title + "Vs" + y_axis_title + "_le.png"
    plt.savefig(output_file)

# Show plot
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = weather_data_df.loc[weather_data_df["Lat"] >= 0]
southern_df = weather_data_df.loc[weather_data_df["Lat"] < 0]
northern_df.head(10)
#southern_df.head(10)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Max Temp vs. Latitude Linear Regression
x_value = northern_df.iloc[:,5]
y_value = northern_df.iloc[:, 7]

linear_regression_plot(x_value,y_value,"north","Latitude","Max Temp",
                       "Northern Hemisphere - Max Temp vs. Latitude Linear Regression",6,-30)

# %%
#In above plot temparature is maximum closer to equator and decrease when moving towards north

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Max Temp vs. Latitude Linear Regression

x_value = southern_df.iloc[:,5]
y_value = southern_df.iloc[:, 7]

linear_regression_plot(x_value,y_value,"south",
                       "Latitude","Max Temp","Southern Hemisphere - Max Temp vs. Latitude Linear Regression",-30,45)

# %%
#In above plot temparature is maximum closer to equator and shows a trend to decrease when moving towards south

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

x_value = northern_df.iloc[:,5]
y_value = northern_df.iloc[:, 4]

linear_regression_plot(x_value,y_value,"north","Latitude","Humidity",
                       "Northern Hemisphere - Humidity(%) vs. Latitude Linear Regression",40,20)

# %%
# The correlation between Latitude and Humidity shows North side has more humidity

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

x_value = southern_df.iloc[:,5]
y_value = southern_df.iloc[:, 4]

linear_regression_plot(x_value,y_value,"south","Latitude","Humidity",
                       "Southern Hemisphere - Humidity(%) vs. Latitude Linear Regression",-30,20)

# %%
# The correlation between Latitude and Humidity shows a poor correlation

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_value = northern_df.iloc[:,5]
y_value= northern_df.iloc[:,1]

linear_regression_plot(x_value,y_value,"north","Latitude","Cloudiness",
                       "Northern Hemisphere - Cloudiness% vs. Latitude Linear Regression",40,20)

# %%
#The above correlations shows that the Cloudinessdont depend on Latitude

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_value = southern_df.iloc[:,5]
y_value = southern_df.iloc[:,1]

linear_regression_plot(x_value,y_value,"south","Latitude","Cloudiness",
                       "Southern Hemisphere - Cloudiness% vs. Latitude Linear Regression",-30,25)

# %%
#The above correlations shows that the Cloudinessdont depend on Latitude

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_value = northern_df.iloc[:,5]
y_value = northern_df.iloc[:,8]

linear_regression_plot(x_value,y_value,"north","Latitude","Wind Speed",
                       "Northern Hemisphere - Wind Speed(mph) vs. Latitude Linear Regression",30,25)

# %%
#The maximum wind speed is observed closer to equator and has poor the correlation with Latitude

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
#Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_value = southern_df.iloc[:,5]
y_value = southern_df.iloc[:,8]

linear_regression_plot(x_value,y_value,"south","Latitude","Wind Speed",
                       "Southern Hemisphere - Wind Speed(mph) vs. Latitude Linear Regression",-30,25)

# %%
#The maximum wind speed is observed closer to equator and has poor the correlation with Latitude
